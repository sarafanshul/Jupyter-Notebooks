# %% [markdown]
# # <center> Histogram
#    <img src='https://matplotlib.org/3.1.0/_static/logo2.png' >

# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
from statistics import median 
# %matplotlib inline

# %% [markdown]
# ## Bar Histograph

# %%
data = pd.read_csv(r'DATA/datahist.csv')
ids = data['Responder_id']
ages = data['Age']
bins = list(range(10 , 81 , 10))
median_age = median(ages)

# %%
plt.style.use('seaborn-deep')
plt.figure( figsize = (10 , 7) , dpi = 80 , facecolor='w' ,edgecolor = 'k')

plt.hist( ages , bins = bins ,color = '#00b894', alpha = 0.5 )

plt.axvline(median_age , color = '#d63031' , alpha = 1 , label = 'Age Median')
plt.title('Histogram')
plt.legend()
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Ages',fontsize=15)
plt.ylabel('Frequency',fontsize=15)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.scatter( ages ,ids )

# %%
plt.style.use('seaborn-white')
plt.figure( figsize = (10 , 7) , dpi = 80 , facecolor='w' ,edgecolor = 'k')

plt.hist2d(ages , ids ,bins=100)
plt.title('Hist-2D')
plt.xlabel('Ages',fontsize=15)
plt.ylabel('Frequency Of Survey Taken',fontsize=15)
# plt.plot(ids , ages)
# Out:
# Text(0, 0.5, 'Frequency Of Survey Taken')

# %% [markdown]
# ## Colored Histograph

# %%
from matplotlib import colors
from matplotlib.ticker import PercentFormatter

# Fixing random state for reproducibility
np.random.seed(19680801)
N_points = 100000
n_bins = 20

# Generate a normal distribution, center at x=0 and y=5
x = np.random.randn(N_points)
y = .4 * x + np.random.randn(100000) + 5

plt.figure( figsize = (10 , 7) , dpi = 80 , facecolor='w' ,edgecolor = 'k')

# N is the count in each bin, bins is the lower-limit of the bin
N, bins, patches = plt.hist(x, bins=n_bins)

# We'll color code by height, but you could use any scalar
fracs = N / N.max()

# we need to normalize the data to 0..1 for the full range of the colormap
norm = colors.Normalize(fracs.min(), fracs.max())

# Now, we'll loop through our objects and set the color of each accordingly
for thisfrac, thispatch in zip(fracs, patches):
    color = plt.cm.viridis(norm(thisfrac))
    thispatch.set_facecolor(color)

# %% [markdown]
# ## 2-D Histograph

# %%
plt.style.use('default')
plt.figure( figsize = (10 , 7) , dpi = 80 , facecolor='w' ,edgecolor = 'k')

plt.hist2d(x , y , bins=100 , norm=colors.LogNorm())

plt.title('2D Histograph')
# Out:
# Text(0.5, 1.0, '2D Histograph')
