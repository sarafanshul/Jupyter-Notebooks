# %% [markdown]
# ## <center> Time Series Data
# <img src='https://miro.medium.com/max/1266/1*Y2v3PrF1rUQRUHwOcXJznA.png'>

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
from matplotlib import dates as mpl_dates
import numpy as np
# %matplotlib inline

# %%
dates = [
    datetime(2019, 5, 24),
    datetime(2019, 5, 25),
    datetime(2019, 5, 26),
    datetime(2019, 5, 27),
    datetime(2019, 5, 28),
    datetime(2019, 5, 29),
    datetime(2019, 5, 30)
]

y = [0, 1, 3, 4, 6, 5, 7]

# %%
plt.style.use('seaborn-white')
plt.figure( figsize = (15 , 7) , facecolor = 'w')

plt.plot_date(dates , y , linestyle = 'solid')
plt.gcf().autofmt_xdate()
date_format = mpl_dates.DateFormatter(' %b , %d %Y')
plt.gca().xaxis.set_major_formatter(date_format)

plt.title('Time Series Data')
# Out:
# Text(0.5, 1.0, 'Time Series Data')

# %%
data = pd.read_csv(r'DATA/timedate.csv')

#For Sorting Dates 
data['Date'] = pd.to_datetime(data['Date'])
data.sort_values( 'Date' , inplace = True)

price_date = data['Date']
price_close = data['Close']

# %%
plt.style.use('seaborn')
plt.figure( figsize = (15 , 7) , facecolor = 'w')

plt.plot_date( price_date , price_close , color = 'green' ,  linestyle = 'solid')
# plt.plot_date( price_date , price_close-100 , linestyle = 'solid')
plt.gcf().autofmt_xdate()
