# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Accesing Table form csv

# %%
data = pd.read_csv(r'DATA/Salaries.csv')

# %%
data
# Out:
#             Id            EmployeeName  \
# 0            1          NATHANIEL FORD
# 1            2            GARY JIMENEZ
# 2            3          ALBERT PARDINI
# 3            4       CHRISTOPHER CHONG
# 4            5         PATRICK GARDNER
# 5            6          DAVID SULLIVAN
# 6            7               ALSON LEE
# 7            8           DAVID KUSHNER
# 8            9          MICHAEL MORRIS
# 9           10      JOANNE HAYES-WHITE
# 10          11           ARTHUR KENNEY
# 11          12        PATRICIA JACKSON
# 12          13       EDWARD HARRINGTON
# 13          14             JOHN MARTIN
# 14          15          DAVID FRANKLIN
# 15          16         RICHARD CORRIEA
# 16          17                AMY HART
# 17          18          SEBASTIAN WONG
# 18          19              MARTY ROSS
# 19          20           ELLEN MOFFATT
# 20          21              VENUS AZAR
# 21          22            JUDY MELINEK
# 22          23           GEORGE GARCIA
# ...

# %% [markdown]
# # cleaning Table

# %%
#data.drop(columns=['Id'] , axis=1)

# %%
#data.drop(columns=['Benefits' , 'Notes' , 'Status'] , axis=1)

# %%
data = data.drop(columns=[ 'Id' , 'Benefits' , 'Notes' , 'Status'] , axis=1)

# %%
data.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay   TotalPay  TotalPayBenefits  Year  \
# 0  167411.18         0.00  400184.25  567595.43         567595.43  2011
# 1  155966.02    245131.88  137811.38  538909.28         538909.28  2011
# 2  212739.13    106088.18   16452.60  335279.91         335279.91  2011
# 3   77916.00     56120.71  198306.90  332343.61         332343.61  2011
# 4  134401.60      9737.00  182234.59  326373.19         326373.19  2011
#
#           Agency
# 0  San Francisco
# 1  San Francisco
# 2  San Francisco
# 3  San Francisco
# 4  San Francisco

# %%
data.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       TotalPay  \
# count  148045.000000  148650.000000  148650.000000  148654.000000
# mean    66325.448841    5066.059886    3648.767297   74768.321972
# std     42764.635495   11454.380559    8056.601866   50517.005274
# min      -166.010000      -0.010000   -7058.590000    -618.130000
# 25%     33588.200000       0.000000       0.000000   36168.995000
# 50%     65007.450000       0.000000     811.270000   71426.610000
# 75%     94691.050000    4658.175000    4236.065000  105839.135000
# max    319275.010000  245131.880000  400184.250000  567595.430000
#
#        TotalPayBenefits           Year
# count     148654.000000  148654.000000
# mean       93692.554811    2012.522643
# std        62793.533483       1.117538
# min         -618.130000    2011.000000
# 25%        44065.650000    2012.000000
# 50%        92404.090000    2013.000000
# 75%       132876.450000    2014.000000
# max       567595.430000    2014.000000

# %%
# mod_data = data[data.BasePay > 0 ]
mod_data = data[data.OtherPay > 0]

# %%
mod_data.describe()
# Out:
#              BasePay    OvertimePay       OtherPay       TotalPay  \
# count  106731.000000  107045.000000  107045.000000  107045.000000
# mean    69912.292188    6837.088046    5067.000252   81611.303558
# std     41349.183207   12960.184860    9107.693900   50798.284138
# min         0.000000      -0.010000       0.300000       0.300000
# 25%     44693.080000       0.000000     624.000000   49224.370000
# 50%     66137.200000    1184.080000    2004.610000   75689.290000
# 75%     97433.295000    7787.120000    6277.040000  114626.040000
# max    319275.010000  245131.880000  400184.250000  567595.430000
#
#        TotalPayBenefits           Year
# count     107045.000000  107045.000000
# mean      101898.603537    2012.499696
# std        62558.947951       1.111330
# min            0.300000    2011.000000
# 25%        57791.110000    2012.000000
# 50%        99118.840000    2012.000000
# 75%       140996.730000    2013.000000
# max       567595.430000    2014.000000

# %%
data.BasePay.plot(style=".-")
