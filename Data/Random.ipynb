# %%
from matplotlib import pyplot as plt
import random
import numpy as np
# %matplotlib inline

# %%
n = 10
N = 1000
# hist = np.zeros(n , 'int32')
hist = [0]*n
mean = 10
#sigma = n//5 works mostly 
sigma =2
x = list(range(len(hist)))

# %%
for _ in range(N):
    r = random.gauss(mean , sigma)
    Bin = int(r - mean//2)
    if Bin < 0 : Bin = 0
    elif Bin >= n: Bin = n - 1
    hist[Bin] += 1

# %%
print(*hist , sep = '\n')
# Out:
# 25
# 42
# 78
# 146
# 199
# 202
# 154
# 85
# 45
# 24

# %%
plt.style.use('seaborn-white')
plt.figure(figsize = (15,7) , dpi = 80)
x_values = np.linspace(-3, 3, 120)
plt.plot(*x_values , hist)
plt.fill_between( x , hist , alpha = 0.5)

# %%
for i in range(10):
    print(random.triangular(1 , 10 , 5))
# Out:
# 2.9518485136068087
# 2.907514125394043
# 7.039011057249011
# 4.730300254491597
# 6.4489326477453055
# 4.306948828742362
# 3.370726304410834
# 6.718950437162434
# 4.204020105611711
# 5.823768752591941

# %%
# Plotting of 1-dimensional Gaussian distribution function

plt.figure(figsize = (10,7) , dpi = 80)
def gaussian(x, mu, sig):
    return np.exp(-np.power(x - mu, 2.) / (2 * np.power(sig, 2.)))

x_values = np.linspace(-3, 3, 120)
for mu, sig in [(-1, 1), (0, 2), (2, 3)]:
    plt.plot(x_values, gaussian(x_values, mu, sig))
