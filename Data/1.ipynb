# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
data = pd.read_csv(r'DATA/weather.csv')

# %%
data[:4]
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN  \
# 0  Andaman & Nicobar Islands  1901  49.2   87.1  29.2    2.3  528.8  517.5
# 1  Andaman & Nicobar Islands  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  Andaman & Nicobar Islands  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  Andaman & Nicobar Islands  1904   9.4   14.7   0.0  202.4  304.5  495.1
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL     JF    MAM    JJAS  \
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2  136.3  560.3  1696.3
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7  159.8  458.3  2185.9
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4  156.7  236.1  1874.0
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6   24.1  506.9  1977.6
#
#      OND
# 0  980.3
# 1  716.7
# 2  690.6
# 3  571.0

# %%
data_mp = data[data.SUBDIVISION == 'West Madhya Pradesh']
data_mh = data[data.SUBDIVISION == 'Madhya Maharashtra']
data_gj = data[data.SUBDIVISION == 'Gujarat Region']
# data_mp.set_index('YEAR').head()

# %%
plt.style.use('default')
plt.figure(figsize =(15 , 6) ,  facecolor='w', edgecolor='k')
plt.grid()
plt.plot(data_mp.YEAR , data_mp.ANNUAL, 'k' ,linewidth=2 )
plt.plot(data_mh.YEAR , data_mh.ANNUAL, '--r' ,linewidth=1.3)
plt.plot(data_gj.YEAR , data_gj.ANNUAL, '--g' ,linewidth=1.3)
#LABEL NOT SHOWING result>>>plt.plot(data_ld.YEAR , data_ld.ANNUAL, 'r' , label='Lakshdweep')
plt.legend([ 'Madhya Pradesh' , 'Maharastra' , 'Gujarat' ])
#COMMON ATTRIBUTES
plt.xlabel('Year')
plt.ylabel('Median Rianfall')
plt.title('Comparision of Median Rainfall by Year')
#plt.plot()
# Out:
# Text(0.5, 1.0, 'Comparision of Median Rainfall by Year')
